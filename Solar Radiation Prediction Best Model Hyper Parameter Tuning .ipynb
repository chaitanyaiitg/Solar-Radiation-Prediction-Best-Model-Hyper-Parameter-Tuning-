# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('F:\Data_Science\Solar Radiation Prediction\Solar Radiation Prediction.csv')

# %%
df
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
#        Pressure  Humidity  WindDirection(Degrees)  Speed TimeSunRise  \
# 0         30.46        59                  177.39   5.62    06:13:00
# 1         30.46        58                  176.78   3.37    06:13:00
# 2         30.46        57                  158.75   3.37    06:13:00
# 3         30.46        60                  137.71   3.37    06:13:00
# 4         30.46        62                  104.95   5.62    06:13:00
# ...         ...       ...                     ...    ...         ...
# 32681     30.43       102                  145.42   6.75    06:41:00
# 32682     30.42       102                  117.78   6.75    06:41:00
# 32683     30.42       102                  145.19   9.00    06:41:00
# 32684     30.42       101                  164.19   7.87    06:41:00
# 32685     30.43       101                   83.59   3.37    06:41:00
#
#       TimeSunSet
# 0       18:13:00
# 1       18:13:00
# 2       18:13:00
# 3       18:13:00
# 4       18:13:00
# ...          ...
# 32681   17:42:00
# 32682   17:42:00
# 32683   17:42:00
# 32684   17:42:00
# 32685   17:42:00
#
# [32686 rows x 11 columns]

# %%
df.shape
# Out:
# (32686, 11)

# %%
df.columns
# Out:
# Index(['UNIXTime', 'Data', 'Time', 'Radiation', 'Temperature', 'Pressure',
#        'Humidity', 'WindDirection(Degrees)', 'Speed', 'TimeSunRise',
#        'TimeSunSet'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# UNIXTime                  0
# Data                      0
# Time                      0
# Radiation                 0
# Temperature               0
# Pressure                  0
# Humidity                  0
# WindDirection(Degrees)    0
# Speed                     0
# TimeSunRise               0
# TimeSunSet                0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.columns
# Out:
# Index(['UNIXTime', 'Data', 'Time', 'Radiation', 'Temperature', 'Pressure',
#        'Humidity', 'WindDirection(Degrees)', 'Speed', 'TimeSunRise',
#        'TimeSunSet'],
#       dtype='object')

# %%
df.drop(['UNIXTime', 'Data', 'Time','TimeSunRise','TimeSunSet'], axis=1,inplace=True)

# %%
df
# Out:
#        Radiation  Temperature  Pressure  Humidity  WindDirection(Degrees)  \
# 0           1.21           48     30.46        59                  177.39
# 1           1.21           48     30.46        58                  176.78
# 2           1.23           48     30.46        57                  158.75
# 3           1.21           48     30.46        60                  137.71
# 4           1.17           48     30.46        62                  104.95
# ...          ...          ...       ...       ...                     ...
# 32681       1.22           44     30.43       102                  145.42
# 32682       1.17           44     30.42       102                  117.78
# 32683       1.20           44     30.42       102                  145.19
# 32684       1.23           44     30.42       101                  164.19
# 32685       1.20           44     30.43       101                   83.59
#
#        Speed
# 0       5.62
# 1       3.37
# 2       3.37
# 3       3.37
# 4       5.62
# ...      ...
# 32681   6.75
# 32682   6.75
# 32683   9.00
# 32684   7.87
# 32685   3.37
#
# [32686 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Radiation', 'Temperature', 'Pressure', 'Humidity',
#        'WindDirection(Degrees)', 'Speed'],
#       dtype='object')

# %%
cols=['Temperature','Pressure','Humidity','WindDirection(Degrees)','Speed']
for i in cols:
    sns.jointplot(x='Radiation',y=i,data=df, kind='reg', color='c')
    plt.title('%s vs %s'%('Radiation',i))

# %%
sns.distplot(df['Radiation'],color='r')

# %%
df['Temperature'].value_counts()
# Out:
# 45    2951
# 48    2610
# 47    2488
# 46    2135
# 50    2097
# 49    2038
# 51    1916
# 52    1557
# 53    1339
# 54    1272
# 44    1237
# 57    1071
# 55    1061
# 58    1021
# 56     988
# 59     921
# 60     790
# 62     679
# 63     678
# 61     659
# 43     615
# 64     528
# 42     422
# 41     395
# 65     257
# 40     230
# 66     146
# 38     107
# 39     100
# 67      96
# 37      93
# 68      51
# 36      38
# 69      36
# 70      36
# 71      17
# 35      10
# 34       1
# Name: Temperature, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Temperature', y='Radiation', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Humidity', y='Radiation', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
X=df.drop('Radiation',axis=1)

# %%
X
# Out:
#        Temperature  Pressure  Humidity  WindDirection(Degrees)  Speed
# 0               48     30.46        59                  177.39   5.62
# 1               48     30.46        58                  176.78   3.37
# 2               48     30.46        57                  158.75   3.37
# 3               48     30.46        60                  137.71   3.37
# 4               48     30.46        62                  104.95   5.62
# ...            ...       ...       ...                     ...    ...
# 32681           44     30.43       102                  145.42   6.75
# 32682           44     30.42       102                  117.78   6.75
# 32683           44     30.42       102                  145.19   9.00
# 32684           44     30.42       101                  164.19   7.87
# 32685           44     30.43       101                   83.59   3.37
#
# [32686 rows x 5 columns]

# %%
y=df['Radiation']

# %%
y
# Out:
# 0        1.21
# 1        1.21
# 2        1.23
# 3        1.21
# 4        1.17
#          ...
# 32681    1.22
# 32682    1.17
# 32683    1.20
# 32684    1.23
# 32685    1.20
# Name: Radiation, Length: 32686, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),cmap='RdYlGn',annot=True)
plt.show()

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.490754   0.08727579 0.14877367 0.20675814 0.0664384 ]

# %%
plt.figure(figsize=(15,10))
feature_imp=pd.Series(selection.feature_importances_, index=X.columns)
feature_imp.nlargest(15).plot(kind='barh')

# %%
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=25)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
lasso=Lasso()
lasso.fit(X_train,y_train)
lasso.score(X_test,y_test)
# Out:
# 0.5630188333647972

# %%
algo=[]
value=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=25)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(name) +': '+ str(cv_score))
    algo.append(name)
    value.append(cv_score)
    
cross_val_score_model(Lasso(),'Lasso')
cross_val_score_model(Ridge(),'Ridge')
cross_val_score_model(KNeighborsRegressor(),'KNeighborsRegressor')
cross_val_score_model(LinearRegression(),'LinearRegression')
cross_val_score_model(DecisionTreeRegressor(),'DecisionTreeRegressor')
cross_val_score_model(RandomForestRegressor(),'RandomForestRegressor')
# Out:
# CV_Score Lasso: 0.5633585395721239
# CV_Score Ridge: 0.5677562926076363
# CV_Score KNeighborsRegressor: 0.6505278135930835
# CV_Score LinearRegression: 0.5677719424931242
# CV_Score DecisionTreeRegressor: 0.508419286331613
# CV_Score RandomForestRegressor: 0.7468199774240495

# %%
sns.barplot(x=value,y=algo)
plt.show()

# %%
model_params={
    'RandomForestRegressor':{
        'model':RandomForestRegressor(),
        'params':{
            'n_estimators' :[100,300,500,1000,1200],
            'max_features' : ['auto', 'sqrt'],
            'max_depth' : [1,5,10,15,20,25,30,35,40,50],
        }
    }

}

# %%
scores=[]
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=25)
for model_name, mp in model_params.items():
    random_clf=RandomizedSearchCV(mp['model'],mp['params'],scoring='neg_mean_squared_error', n_iter = 5, cv = cv, verbose=2, n_jobs = 1, return_train_score=False)
    random_clf.fit(X,y)
    scores.append({
        'model':model_name,
        'best_score':random_clf.best_score_,
        'best param':random_clf.best_params_,
        'best estimator':random_clf.best_estimator_
    })

ds=pd.DataFrame(scores,columns=['model','best param'])
ds
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] n_estimators=1200, max_features=auto, max_depth=10 ..............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=1200, max_features=auto, max_depth=10, total= 1.2min
# [CV] n_estimators=1200, max_features=auto, max_depth=10 ..............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.2min remaining:    0.0s
# [CV]  n_estimators=1200, max_features=auto, max_depth=10, total= 1.2min
# [CV] n_estimators=1200, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=10, total= 1.2min
# [CV] n_estimators=1200, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=10, total= 1.2min
# [CV] n_estimators=1200, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=10, total= 1.2min
# [CV] n_estimators=1200, max_features=auto, max_depth=50 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=50, total= 2.6min
# [CV] n_estimators=1200, max_features=auto, max_depth=50 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=50, total= 2.6min
# [CV] n_estimators=1200, max_features=auto, max_depth=50 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=50, total= 2.6min
# [CV] n_estimators=1200, max_features=auto, max_depth=50 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=50, total= 2.6min
# [CV] n_estimators=1200, max_features=auto, max_depth=50 ..............
# [CV]  n_estimators=1200, max_features=auto, max_depth=50, total= 2.6min
# [CV] n_estimators=1000, max_features=sqrt, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=sqrt, max_depth=10, total=  29.7s
# [CV] n_estimators=1000, max_features=sqrt, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=sqrt, max_depth=10, total=  29.4s
# [CV] n_estimators=1000, max_features=sqrt, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=sqrt, max_depth=10, total=  29.6s
# [CV] n_estimators=1000, max_features=sqrt, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=sqrt, max_depth=10, total=  30.5s
# [CV] n_estimators=1000, max_features=sqrt, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=sqrt, max_depth=10, total=  30.0s
# [CV] n_estimators=1000, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=auto, max_depth=10, total=  59.9s
# [CV] n_estimators=1000, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=auto, max_depth=10, total= 1.0min
# [CV] n_estimators=1000, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=auto, max_depth=10, total=  60.0s
# [CV] n_estimators=1000, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=auto, max_depth=10, total= 1.0min
# [CV] n_estimators=1000, max_features=auto, max_depth=10 ..............
# [CV]  n_estimators=1000, max_features=auto, max_depth=10, total= 1.0min
# [CV] n_estimators=500, max_features=auto, max_depth=10 ...............
# [CV]  n_estimators=500, max_features=auto, max_depth=10, total=  33.5s
# [CV] n_estimators=500, max_features=auto, max_depth=10 ...............
# [CV]  n_estimators=500, max_features=auto, max_depth=10, total=  33.7s
# [CV] n_estimators=500, max_features=auto, max_depth=10 ...............
# [CV]  n_estimators=500, max_features=auto, max_depth=10, total=  32.8s
# [CV] n_estimators=500, max_features=auto, max_depth=10 ...............
# [CV]  n_estimators=500, max_features=auto, max_depth=10, total=  36.0s
# [CV] n_estimators=500, max_features=auto, max_depth=10 ...............
# [CV]  n_estimators=500, max_features=auto, max_depth=10, total=  35.7s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 29.3min finished
#                    model                                         best param
# 0  RandomForestRegressor  {'n_estimators': 1200, 'max_features': 'auto',...

# %%
def display_text_max_col_width(df, width):
    with pd.option_context('display.max_colwidth', width):
        print(df)

display_text_max_col_width(ds['best param'], 800)
# Out:
# 0    {'n_estimators': 1200, 'max_features': 'auto', 'max_depth': 50}
# Name: best param, dtype: object

# %%
cross_val_score_model(RandomForestRegressor(n_estimators=1200, max_features='auto', max_depth=50),'RandomForestRegressor_best')
# Out:
# CV_Score RandomForestRegressor_best: 0.7486630501794374

# %%
sns.barplot(x=value,y=algo)
plt.show()

# %%
Best1=pd.Series(algo)
Best2=pd.Series(value)
pd.DataFrame({'Model':Best1,'CVScore':Best2})
# Out:
#                         Model   CVScore
# 0                       Lasso  0.563359
# 1                       Ridge  0.567756
# 2         KNeighborsRegressor  0.650528
# 3            LinearRegression  0.567772
# 4       DecisionTreeRegressor  0.508419
# 5       RandomForestRegressor  0.746820
# 6  RandomForestRegressor_best  0.748663

# %%
from sklearn.metrics import r2_score
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
rf_y_pred=rf.predict(X_test)
score=r2_score(y_test,rf_y_pred)
score
# Out:
# 0.7444822082595186

# %%
from sklearn.metrics import r2_score
rf_best=RandomForestRegressor(n_estimators=1200, max_features='auto', max_depth=50)
rf_best.fit(X_train,y_train)
rf_best_y_pred=rf_best.predict(X_test)
score1=r2_score(y_test,rf_best_y_pred)
score1
# Out:
# 0.7466876971795361

# %%
sns.distplot(y_test-rf_best_y_pred)

# %%
plt.scatter(y_test,rf_best_y_pred)

# %%
df.iloc[1000]
# Out:
# Radiation                 757.01
# Temperature                57.00
# Pressure                   30.45
# Humidity                   69.00
# WindDirection(Degrees)     61.23
# Speed                      10.12
# Name: 1000, dtype: float64

# %%
a=[[57,30.45,69,61.23,10.12]]
a=s.transform(a)
b=rf_best.predict(a)
b
# Out:
# array([755.21405833])
